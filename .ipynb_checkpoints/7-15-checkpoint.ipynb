# %%
1+1
# Out:
# 2

# %%
2**3
# Out:
# 8

# %%
6/4
# Out:
# 1.5

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.sin(1)
# Out:
# 0.8414709848078965

# %%
np.cos(0.5)
# Out:
# 0.8775825618903728

# %%
plt.plot([0,1,2,3,4,5,6])
#plt.plot(X,Y)
#點的X座標的list, 點的Y座標的list

# %%
X=[0,1.5,3.5,4.9,6.8,7.7,10]
Y=[0,1,2,3,4,5,6]
#宣告X, Y為何

# %%
plt.plot(X,Y)

# %%
plt.plot([X,Y])
# Out:
# [<matplotlib.lines.Line2D at 0x1c49561f240>,
#  <matplotlib.lines.Line2D at 0x1c49561f390>,
#  <matplotlib.lines.Line2D at 0x1c49561f4e0>,
#  <matplotlib.lines.Line2D at 0x1c49561f630>,
#  <matplotlib.lines.Line2D at 0x1c49561f780>,
#  <matplotlib.lines.Line2D at 0x1c49561f8d0>,
#  <matplotlib.lines.Line2D at 0x1c49561fa20>]

# %%
np.random.rand(10)
# Out:
# array([0.38629142, 0.18892681, 0.41899416, 0.90947231, 0.88438964,
#        0.29669211, 0.49061609, 0.32405419, 0.45079084, 0.72788811])

# %%
np.random.randn(10)
# Out:
# array([-0.51776951, -1.41986499,  1.22793976,  0.08834925, -0.58403281,
#        -0.21574335,  0.35557618,  1.73765688, -0.70586741,  0.4240111 ])

# %%
plt.plot(np.random.randn(100))

# %%
plt.scatter(X, Y)

# %%
X=np.random.randn(200)
Y=np.random.randn(200)

# %%
plt.scatter(X, Y)

# %%
X=np.random.randn(100)
Y=X**2+1

# %%
plt.scatter(X, Y)

# %%
X=np.linspace(10, 20, 300)
Y=X**2+1

# %%
plt.xkcd()

# %%
plt.scatter(X, Y)

# %%
X = np.linspace(10, 20, 300)

# %%
Y = np.sin(X)+1

# %%
plt.plot(x, y)

# %%
x = np.linspace(0, 10, 1000)

# %%
y = np.sin(x)

# %%
plt.plot(x, y)

# %%
x = np.linspace(0, 20, 10000)

# %%
y = np.tan(x)

# %%
plt.plot(x, y)

# %%
π=np.pi

# %%
θ = np.linspace(0, 2*π, 500)

# %%
r=3
x=r*np.cos(θ)
y=r*np.sin(θ)

# %%
plt.plot(x, y)

# %%
plt.scatter(x, y)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 2*π, 100)
y = 1/(np.cos(x))
plt.plot(x, y)
